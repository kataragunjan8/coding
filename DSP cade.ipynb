# %% [markdown]
# ## Question:5

# %%
##  que:5

import thinkdsp as t
import thinkplot
from IPython.display import Audio

s1 = t.SinSignal(freq = 240, amp = 1, offset = 0)
w1 = s1.make_wave(start = 0, duration = 1, framerate = 48000)
s2 = t.SinSignal(freq = 270, amp = 2, offset = 0)
w2 = s2.make_wave(start = 1, duration = 1, framerate = 48000)
s3 = t.SinSignal(freq = 300, amp = 1, offset = 0)
w3 = s3.make_wave(start = 2, duration = 1, framerate = 48000)
s4 = t.SinSignal(freq = 337.5,amp = 1,offset = 0)
w4 = s4.make_wave(start = 3, duration = 1, framerate = 48000)
s5 = t.SinSignal(freq = 360,amp = 2,offset = 0)
w5 = s5.make_wave(start = 4, duration = 1, framerate = 48000)
s6 = t.SinSignal(freq = 400,amp = 2,offset = 0)
w6 = s6.make_wave(start = 5, duration = 1, framerate = 48000)
s7 = t.SinSignal(freq = 450,amp = 2,offset = 0)
w7 = s7.make_wave(start = 6, duration = 1, framerate = 48000)
s8 = t.SinSignal(freq = 240,amp = 2,offset = 0)
w8 = s8.make_wave(start = 7, duration = 1, framerate = 48000)

add = w1 + w2 + w3 + w4 + w5 +w6 + w7 + w8

audio = Audio(data = add.ys, rate = add.framerate)
audio
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Question:4

# %%
## que:4   
import thinkdsp as t
import thinkplot as p
from IPython.display import Audio

wave = t.read_wave('Downloads/natural.wav')
wave.plot()

seg = wave.segment(start = 0, duration = 5)
spe = seg.make_spectrum()
spe.plot(high = 2000)
spe.low_pass(400)
#spe.make_wave().make_audio()

wave.make_audio()   ## original audio
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spe.make_wave().make_audio()   ## after filtering
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Question:1

# %%
# Que:1

import thinkdsp as t
import thinkplot 

sig1 = t.SinSignal(freq = 11, amp = 2, offset = 0)
sig2 = t.SinSignal(freq = 3, amp = 1, offset = 0)
sig3 = t.SinSignal(freq = 2000, amp = 2, offset = 0)

mix = sig1+sig2+sig3
wave = mix.make_wave(start = 1, duration = 3, framerate = 48000)

wave.make_spectrum().plot()
